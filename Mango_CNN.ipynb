# %% [markdown]
# ## REQUIREMENTS

# %%
# !pip install efficientnet_pytorch

import torch
import torch.nn as nn
from torchvision.io import read_image
from torch.utils.data import Dataset
from torchvision.io import read_image
from efficientnet_pytorch import EfficientNet
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import random
import os
import numpy as np

seed = 123
random.seed(seed)
np.random.seed(seed)
_ = torch.manual_seed(seed)
_ = torch.cuda.manual_seed(seed)

# we select to work on GPU if it is available in the machine, otherwise
# will run on CPU
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet_pytorch) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->efficientnet_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet_pytorch) (3.0.2)
# Building wheels for collected packages: efficientnet_pytorch
#   Building wheel for efficientnet_pytorch (setup.py) ... done
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16424 sha256=796c52704181e7bf021bf3254fff46bdc3ab2349ecf3622071f5d2a7c2347b01
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet_pytorch
# Installing collected packages: efficientnet_pytorch
# Successfully installed efficientnet_pytorch-0.7.1

# %% [markdown]
# ## Defining our Neural Network

# %%
# Definim la classe MangoNet que hereta d'EfficientNet
class MangoNet(nn.Module):
    def __init__(self, num_channels=11*(33+1),drop=0.5):
        # Carrega EfficientNet-B1 preentrenat
        super(MangoNet, self).__init__()
        # Carrega el model EfficientNet-B1 amb pesos preentrenats
        efficient_net = EfficientNet.from_pretrained('efficientnet-b2')

        # Obté el nombre d'entrades de l'última capa fully connected original
        self.features = nn.Sequential(
            efficient_net._conv_stem,
            efficient_net._bn0,
            *efficient_net._blocks,
            efficient_net._conv_head,
            efficient_net._bn1,
        )
        in_features = efficient_net._fc.in_features

        # Substitueix l'última capa amb una nova capa Conv2d per tenir la sortida amb els canals desitjats
        self.avgpool = nn.AdaptiveAvgPool2d(1)
        self.classifier = nn.Sequential(
            nn.Dropout(p=drop, inplace=True),
            nn.Linear(in_features, num_channels),
        )


    def forward(self, x):
        # Passa l'entrada a través de les capes de features d'EfficientNet
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        # Aplica la nostra capa Conv2d personalitzada per obtenir la sortida desitjada
        x = self.classifier(x)
        x = torch.reshape(x, [-1,34,11])
        return x

# %% [markdown]
# ## Importing the dataest

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/datathon-fme-mango.zip'
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: archive/images/images/88_49713919_67042010-37_.jpg
#   inflating: archive/images/images/88_49713920_67042010-56_.jpg
#   inflating: archive/images/images/88_49713921_67042910-02_.jpg
#   inflating: archive/images/images/88_49713922_67042910-56_.jpg
#   inflating: archive/images/images/88_49713923_67042910-99_.jpg
#   inflating: archive/images/images/88_49713924_67042913-TC_.jpg
#   inflating: archive/images/images/88_49713925_67042913-TO_.jpg
#   inflating: archive/images/images/88_49713928_67050465-01_B.jpg
#   inflating: archive/images/images/88_49713929_67050465-TN_B.jpg
#   inflating: archive/images/images/88_49713930_67050466-99_.jpg
#   inflating: archive/images/images/88_49713934_67051010-95_.jpg
#   inflating: archive/images/images/88_49713935_67051011-08_.jpg
#   inflating: archive/images/images/88_49713936_67053266-56_B.jpg
#   inflating: archive/images/images/88_49713937_67053685-08_B.jpg
#   inflating: archive/images/images/88_49713938_67060652-56_B.jpg
#   inflating: archive/images/images/88_49713939_67060652-68_B.jpg
#   inflating: archive/images/images/88_49713940_67060669-92_.jpg
#   inflating: archive/images/images/88_49713941_67060673-02_.jpg
#   inflating: archive/images/images/88_49713942_67061010-02_.jpg
#   inflating: archive/images/images/88_49713943_67070468-99_.jpg
#   inflating: archive/images/images/88_49713944_67070469-01_.jpg
#   inflating: archive/images/images/88_49713945_67070469-99_.jpg
#   inflating: archive/images/images/88_49713946_67072912-TC_.jpg
#   inflating: archive/images/images/88_49713947_67072912-TM_.jpg
#   inflating: archive/images/images/88_49713948_67074013-56_B.jpg
#   inflating: archive/images/images/88_49713949_67080463-01_B.jpg
#   inflating: archive/images/images/88_49713951_67080463-TC_B.jpg
#   inflating: archive/images/images/88_49713952_67080463-TM_.jpg
#   inflating: archive/images/images/88_49713953_67080463-TN_B.jpg
#   inflating: archive/images/images/88_49713954_67080467-02_B.jpg
#   inflating: archive/images/images/88_49713955_67080674-01_.jpg
#   inflating: archive/images/images/88_49713956_67080674-TM_.jpg
#   inflating: archive/images/images/88_49713957_67082912-02_.jpg
#   inflating: archive/images/images/88_49713958_67082912-52_.jpg
#   inflating: archive/images/images/88_49713959_67090464-TM_B.jpg
#   inflating: archive/images/images/88_49713960_67090464-TO_B.jpg
#   inflating: archive/images/images/88_49713961_67090468-99_.jpg
#   inflating: archive/images/images/88_49713962_67090669-01_B.jpg
#   inflating: archive/images/images/88_49713963_67090669-TG_.jpg
#   inflating: archive/images/images/88_49713964_67090669-TM_B.jpg
#   inflating: archive/images/images/88_49713966_67091009-56_.jpg
#   inflating: archive/images/images/88_49713967_67093684-31_B.jpg
#   inflating: archive/images/images/88_49713968_67093684-37_.jpg
#   inflating: archive/images/images/88_49713969_67094012-37_.jpg
#   inflating: archive/images/images/88_49713970_67094440-99_.jpg
#   inflating: archive/images/images/88_49714006_67000468-02_.jpg
#   inflating: archive/images/images/88_49714007_67000476-PL_.jpg
#   inflating: archive/images/images/88_49714008_67000677-TM_.jpg
#   inflating: archive/images/images/88_49714009_67000679-TG_.jpg
#   inflating: archive/images/images/88_49714010_67000680-TO_.jpg
#   inflating: archive/images/images/88_49714011_67002536-TM_B.jpg
#   inflating: archive/images/images/88_49714012_67003708-07_.jpg
#   inflating: archive/images/images/88_49714013_67003709-02_.jpg
#   inflating: archive/images/images/88_49714014_67003710-02_.jpg
#   inflating: archive/images/images/88_49714015_67003711-68_.jpg
#   inflating: archive/images/images/88_49714016_67003712-02_.jpg
#   inflating: archive/images/images/88_49714021_67010457-08_.jpg
#   inflating: archive/images/images/88_49714022_67010472-52_.jpg
#   inflating: archive/images/images/88_49714023_67012532-TM_.jpg
#   inflating: archive/images/images/88_49714024_67012534-37_B.jpg
#   inflating: archive/images/images/88_49714025_67012916-95_.jpg
#   inflating: archive/images/images/88_49714026_67012917-01_.jpg
#   inflating: archive/images/images/88_49714028_67012919-08_.jpg
#   inflating: archive/images/images/88_49714029_67013692-56_.jpg
#   inflating: archive/images/images/88_49714030_67013693-02_.jpg
#   inflating: archive/images/images/88_49714031_67013694-02_.jpg
#   inflating: archive/images/images/88_49714032_67013695-07_.jpg
#   inflating: archive/images/images/88_49714034_67014775-02_.jpg
#   inflating: archive/images/images/88_49714035_67020469-99_.jpg
#   inflating: archive/images/images/88_49714038_67020671-09_.jpg
#   inflating: archive/images/images/88_49714039_67022531-40_B.jpg
#   inflating: archive/images/images/88_49714040_67022533-05_.jpg
#   inflating: archive/images/images/88_49714041_67022534-70_.jpg
#   inflating: archive/images/images/88_49714042_67022913-82_.jpg
#   inflating: archive/images/images/88_49714044_67023686-68_B.jpg
#   inflating: archive/images/images/88_49714045_67024772-02_B.jpg
#   inflating: archive/images/images/88_49714046_67024773-02_B.jpg
#   inflating: archive/images/images/88_49714050_67030469-01_.jpg
#   inflating: archive/images/images/88_49714052_67030655-52_.jpg
#   inflating: archive/images/images/88_49714053_67030676-08_.jpg
#   inflating: archive/images/images/88_49714054_67031011-TC_.jpg
#   inflating: archive/images/images/88_49714055_67031011-TM_.jpg
#   inflating: archive/images/images/88_49714056_67032529-TC_B.jpg
#   inflating: archive/images/images/88_49714057_67032530-40_.jpg
#   inflating: archive/images/images/88_49714060_67032913-99_.jpg
#   inflating: archive/images/images/88_49714061_67032914-05_.jpg
#   inflating: archive/images/images/88_49714062_67032915-02_.jpg
#   inflating: archive/images/images/88_49714064_67034771-02_B.jpg
#   inflating: archive/images/images/88_49714065_67034772-02_B.jpg
#   inflating: archive/images/images/88_49714070_67040469-35_.jpg
#   inflating: archive/images/images/88_49714071_67040470-92_.jpg
#   inflating: archive/images/images/88_49714072_67040671-02_.jpg
#   inflating: archive/images/images/88_49714073_67040671-TC_.jpg
#   inflating: archive/images/images/88_49714074_67040675-92_.jpg
#   inflating: archive/images/images/88_49714075_67040676-08_.jpg
#   inflating: archive/images/images/88_49714076_67042531-70_.jpg
#   inflating: archive/images/images/88_49714077_67042914-43_.jpg
#   inflating: archive/images/images/88_49714079_67042916-37_.jpg
#   inflating: archive/images/images/88_49714080_67042916-99_.jpg
#   inflating: archive/images/images/88_49714081_67043685-TC_B.jpg
#   inflating: archive/images/images/88_49714082_67044441-56_.jpg
#   inflating: archive/images/images/88_49714083_67044442-08_.jpg
#   inflating: archive/images/images/88_49714084_67044442-56_.jpg
#   inflating: archive/images/images/88_49714087_67044774-83_.jpg
#   inflating: archive/images/images/88_49714088_67050468-06_.jpg
#   inflating: archive/images/images/88_49714089_67050469-08_.jpg
#   inflating: archive/images/images/88_49714090_67050675-56_.jpg
#   inflating: archive/images/images/88_49714092_67052528-TM_B.jpg
#   inflating: archive/images/images/88_49714093_67052909-01_.jpg
#   inflating: archive/images/images/88_49714094_67052909-43_.jpg
#   inflating: archive/images/images/88_49714095_67052909-52_.jpg
#   inflating: archive/images/images/88_49714096_67052909-99_.jpg
#   inflating: archive/images/images/88_49714097_67052913-52_.jpg
#   inflating: archive/images/images/88_49714098_67052913-56_.jpg
#   inflating: archive/images/images/88_49714099_67052914-37_.jpg
#   inflating: archive/images/images/88_49714100_67052916-TG_.jpg
#   inflating: archive/images/images/88_49714101_67053684-02_B.jpg
#   inflating: archive/images/images/88_49714102_67053684-TC_B.jpg
#   inflating: archive/images/images/88_49714103_67054015-07_.jpg
#   inflating: archive/images/images/88_49714104_67054016-56_.jpg
#   inflating: archive/images/images/88_49714105_67054770-02_B.jpg
#   inflating: archive/images/images/88_49714107_67054773-01_.jpg
#   inflating: archive/images/images/88_49714108_67060467-78_.jpg
#   inflating: archive/images/images/88_49714109_67060467-OR_.jpg
#   inflating: archive/images/images/88_49714110_67060469-35_.jpg
#   inflating: archive/images/images/88_49714111_67060654-54_.jpg
#   inflating: archive/images/images/88_49714112_67060667-75_.jpg
#   inflating: archive/images/images/88_49714115_67062531-05_.jpg
#   inflating: archive/images/images/88_49714116_67062913-50_.jpg
#   inflating: archive/images/images/88_49714117_67062914-02_.jpg
#   inflating: archive/images/images/88_49714118_67062914-37_.jpg
#   inflating: archive/images/images/88_49714119_67063266-TM_.jpg
#   inflating: archive/images/images/88_49714120_67063266-TN_B.jpg
#   inflating: archive/images/images/88_49714121_67063266-TO_B.jpg
#   inflating: archive/images/images/88_49714122_67063685-50_.jpg
#   inflating: archive/images/images/88_49714124_67064772-05_.jpg
#   inflating: archive/images/images/88_49714125_67070470-99_.jpg
#   inflating: archive/images/images/88_49714126_67070670-01_.jpg
#   inflating: archive/images/images/88_49714127_67070670-TC_.jpg
#   inflating: archive/images/images/88_49714128_67070675-07_.jpg
#   inflating: archive/images/images/88_49714129_67072531-05_.jpg
#   inflating: archive/images/images/88_49714130_67072915-99_.jpg
#   inflating: archive/images/images/88_49714131_67073684-TC_B.jpg
#   inflating: archive/images/images/88_49714132_67074014-07_.jpg
#   inflating: archive/images/images/88_49714133_67074771-85_.jpg
#   inflating: archive/images/images/88_49714135_67080468-35_.jpg
#   inflating: archive/images/images/88_49714136_67080470-99_.jpg
#   inflating: archive/images/images/88_49714137_67080675-95_.jpg
#   inflating: archive/images/images/88_49714140_67084013-56_.jpg
#   inflating: archive/images/images/88_49714141_67084437-02_.jpg
#   inflating: archive/images/images/88_49714142_67084437-99_.jpg
#   inflating: archive/images/images/88_49714146_67090674-85_.jpg
#   inflating: archive/images/images/88_49714150_67092911-05_.jpg
#   inflating: archive/images/images/88_49714151_67092911-56_.jpg
#   inflating: archive/images/images/88_49714152_67092911-99_.jpg
#   inflating: archive/images/images/88_49714153_67092913-01_.jpg
#   inflating: archive/images/images/88_49714154_67092914-08_.jpg
#   inflating: archive/images/images/88_49714155_67092915-92_.jpg
#   inflating: archive/images/images/88_49714157_67094442-02_.jpg
#   inflating: archive/images/images/88_49714158_67094442-99_.jpg
#   inflating: archive/images/images/88_49714328_67000681-TM_.jpg
#   inflating: archive/images/images/88_49714329_67000682-TN_.jpg
#   inflating: archive/images/images/88_49714339_67020658-CU_.jpg
#   inflating: archive/images/images/88_49714340_67020664-95_.jpg
#   inflating: archive/images/images/88_49714341_67022532-70_.jpg
#   inflating: archive/images/images/88_49714346_67030657-78_.jpg
#   inflating: archive/images/images/88_49714347_67033266-69_B.jpg
#   inflating: archive/images/images/88_49714350_67040656-99_.jpg
#   inflating: archive/images/images/88_49714351_67040668-02_B.jpg
#   inflating: archive/images/images/88_49714355_67050667-56_.jpg
#   inflating: archive/images/images/88_49714357_67054775-OR_.jpg
#   inflating: archive/images/images/88_49714358_67054776-OR_.jpg
#   inflating: archive/images/images/88_49714359_67060468-05_.jpg
#   inflating: archive/images/images/88_49714360_67060471-43_.jpg
#   inflating: archive/images/images/88_49714361_67060471-92_.jpg
#   inflating: archive/images/images/88_49714362_67062530-70_.jpg
#   inflating: archive/images/images/88_49714364_67070676-56_.jpg
#   inflating: archive/images/images/88_49714365_67074443-09_.jpg
#   inflating: archive/images/images/88_49714367_67080469-99_.jpg
#   inflating: archive/images/images/88_49714368_67082530-43_.jpg
#   inflating: archive/images/images/88_49714369_67082530-81_.jpg
#   inflating: archive/images/images/88_49714370_67082913-99_.jpg
#   inflating: archive/images/images/88_49714371_67084438-08_.jpg
#   inflating: archive/images/images/88_49714372_67084438-56_.jpg
#   inflating: archive/images/images/88_49714376_67092530-70_.jpg
#   inflating: archive/images/images/88_49714677_67000474-09_.jpg
#   inflating: archive/images/images/88_49714678_67000474-99_.jpg
#   inflating: archive/images/images/88_49714679_67002534-99_.jpg
#   inflating: archive/images/images/88_49714680_67002534-CU_.jpg
#   inflating: archive/images/images/88_49714681_67003274-TM_.jpg
#   inflating: archive/images/images/88_49714682_67010373-69_.jpg
#   inflating: archive/images/images/88_49714683_67010474-50_.jpg
#   inflating: archive/images/images/88_49714684_67010475-70_.jpg
#   inflating: archive/images/images/88_49714685_67010679-56_B.jpg
#   inflating: archive/images/images/88_49714686_67012536-80_.jpg
#   inflating: archive/images/images/88_49714687_67012536-99_.jpg
#   inflating: archive/images/images/88_49714688_67013696-50_.jpg
#   inflating: archive/images/images/88_49714689_67020473-52_.jpg
#   inflating: archive/images/images/88_49714690_67023265-99_.jpg
#   inflating: archive/images/images/88_49714691_67023687-52_.jpg
#   inflating: archive/images/images/88_49714692_67030678-07_B.jpg
#   inflating: archive/images/images/88_49714693_67032531-05_.jpg
#   inflating: archive/images/images/88_49714694_67032532-37_.jpg
#   inflating: archive/images/images/88_49714695_67032532-88_.jpg
#   inflating: archive/images/images/88_49714696_67032916-01_.jpg
#   inflating: archive/images/images/88_49714697_67032916-94_.jpg
#   inflating: archive/images/images/88_49714698_67032916-99_.jpg
#   inflating: archive/images/images/88_49714699_67033686-56_.jpg
#   inflating: archive/images/images/88_49714700_67040373-69_.jpg
#   inflating: archive/images/images/88_49714701_67042911-01_.jpg
#   inflating: archive/images/images/88_49714702_67042911-37_.jpg
#   inflating: archive/images/images/88_49714703_67042911-95_.jpg
#   inflating: archive/images/images/88_49714704_67043686-09_B.jpg
#   inflating: archive/images/images/88_49714705_67046312-30_.jpg
#   inflating: archive/images/images/88_49714706_67050677-02_.jpg
#   inflating: archive/images/images/88_49714707_67052530-05_.jpg
#   inflating: archive/images/images/88_49714708_67053686-16_B.jpg
#   inflating: archive/images/images/88_49714709_67056311-37_.jpg
#   inflating: archive/images/images/88_49714710_67060472-43_.jpg
#   inflating: archive/images/images/88_49714711_67060653-99_.jpg
#   inflating: archive/images/images/88_49714712_67060675-99_.jpg
#   inflating: archive/images/images/88_49714713_67063686-52_.jpg
#   inflating: archive/images/images/88_49714714_67066311-30_.jpg
#   inflating: archive/images/images/88_49714715_67072530-05_.jpg
#   inflating: archive/images/images/88_49714716_67072916-52_.jpg
#   inflating: archive/images/images/88_49714717_67073685-56_B.jpg
#   inflating: archive/images/images/88_49714718_67073685-60_B.jpg
#   inflating: archive/images/images/88_49714719_67073686-02_B.jpg
#   inflating: archive/images/images/88_49714720_67075138-08_.jpg
#   inflating: archive/images/images/88_49714721_67080666-75_B.jpg
#   inflating: archive/images/images/88_49714722_67081505-07_B.jpg
#   inflating: archive/images/images/88_49714723_67081505-91_B.jpg
#   inflating: archive/images/images/88_49714724_67082527-70_.jpg
#   inflating: archive/images/images/88_49714725_67082527-85_.jpg
#   inflating: archive/images/images/88_49714726_67082528-02_.jpg
#   inflating: archive/images/images/88_49714727_67082531-88_.jpg
#   inflating: archive/images/images/88_49714728_67082914-03_B.jpg
#   inflating: archive/images/images/88_49714729_67082914-52_B.jpg
#   inflating: archive/images/images/88_49714730_67082916-99_.jpg
#   inflating: archive/images/images/88_49714731_67083685-06_.jpg
#   inflating: archive/images/images/88_49714732_67083685-37_.jpg
#   inflating: archive/images/images/88_49714733_67084441-01_.jpg
#   inflating: archive/images/images/88_49714734_67084441-50_.jpg
#   inflating: archive/images/images/88_49714735_67090471-20_.jpg
#   inflating: archive/images/images/88_49714736_67090664-75_.jpg
#   inflating: archive/images/images/88_49714737_67090666-75_.jpg
#   inflating: archive/images/images/88_49714738_67092531-37_.jpg
#   inflating: archive/images/images/88_49714739_67092531-88_.jpg
#   inflating: archive/images/images/88_49714740_67093265-TC_.jpg
#   inflating: archive/images/images/88_49714741_67093265-TM_.jpg
#   inflating: archive/images/images/88_49714742_67094013-TM_.jpg
#   inflating: archive/images/images/88_49714743_67096310-37_.jpg
#   inflating: archive/images/images/88_49714896_67000475-OR_.jpg
#   inflating: archive/images/images/88_49714897_67010471-30_.jpg
#   inflating: archive/images/images/88_49714899_67010680-01_.jpg
#   inflating: archive/images/images/88_49714900_67010681-TN_.jpg
#   inflating: archive/images/images/88_49714901_67012923-07_.jpg
#   inflating: archive/images/images/88_49714902_67013271-02_B.jpg
#   inflating: archive/images/images/88_49714903_67013272-52_B.jpg
#   inflating: archive/images/images/88_49714904_67016733-09_.jpg
#   inflating: archive/images/images/88_49714905_67020471-07_B.jpg
#   inflating: archive/images/images/88_49714906_67020679-50_B.jpg
#   inflating: archive/images/images/88_49714907_67020679-81_.jpg
#   inflating: archive/images/images/88_49714908_67022536-88_.jpg
#   inflating: archive/images/images/88_49714909_67022917-56_.jpg
#   inflating: archive/images/images/88_49714910_67023271-05_.jpg
#   inflating: archive/images/images/88_49714911_67023271-99_.jpg
#   inflating: archive/images/images/88_49714912_67026314-08_.jpg
#   inflating: archive/images/images/88_49714913_67030631-45_.jpg
#   inflating: archive/images/images/88_49714914_67030679-TM_.jpg
#   inflating: archive/images/images/88_49714915_67032533-70_.jpg
#   inflating: archive/images/images/88_49714916_67033269-09_.jpg
#   inflating: archive/images/images/88_49714917_67033269-43_.jpg
#   inflating: archive/images/images/88_49714918_67035979-54_.jpg
#   inflating: archive/images/images/88_49714919_67035980-78_.jpg
#   inflating: archive/images/images/88_49714920_67035981-56_.jpg
#   inflating: archive/images/images/88_49714921_67036313-01_.jpg
#   inflating: archive/images/images/88_49714922_67040678-50_.jpg
#   inflating: archive/images/images/88_49714924_67041506-08_B.jpg
#   inflating: archive/images/images/88_49714925_67041506-40_B.jpg
#   inflating: archive/images/images/88_49714926_67042532-70_.jpg
#   inflating: archive/images/images/88_49714927_67042533-88_.jpg
#   inflating: archive/images/images/88_49714928_67042917-56_.jpg
#   inflating: archive/images/images/88_49714929_67043267-16_B.jpg
#   inflating: archive/images/images/88_49714930_67045979-54_.jpg
#   inflating: archive/images/images/88_49714931_67045980-78_.jpg
#   inflating: archive/images/images/88_49714932_67045981-56_.jpg
#   inflating: archive/images/images/88_49714933_67046313-08_.jpg
#   inflating: archive/images/images/88_49714934_67050679-99_.jpg
#   inflating: archive/images/images/88_49714935_67051505-04_.jpg
#   inflating: archive/images/images/88_49714936_67051505-56_.jpg
#   inflating: archive/images/images/88_49714937_67051505-99_.jpg
#   inflating: archive/images/images/88_49714938_67052009-56_.jpg
#   inflating: archive/images/images/88_49714939_67052009-99_.jpg
#   inflating: archive/images/images/88_49714940_67052531-08_B.jpg
#   inflating: archive/images/images/88_49714941_67052531-17_B.jpg
#   inflating: archive/images/images/88_49714942_67052531-36_.jpg
#   inflating: archive/images/images/88_49714943_67052531-56_.jpg
#   inflating: archive/images/images/88_49714944_67052532-01_.jpg
#   inflating: archive/images/images/88_49714945_67052533-88_.jpg
#   inflating: archive/images/images/88_49714946_67052915-92_.jpg
#   inflating: archive/images/images/88_49714947_67054444-06_.jpg
#   inflating: archive/images/images/88_49714948_67056312-01_.jpg
#   inflating: archive/images/images/88_49714949_67060677-07_B.jpg
#   inflating: archive/images/images/88_49714950_67062915-07_.jpg
#   inflating: archive/images/images/88_49714951_67062915-56_.jpg
#   inflating: archive/images/images/88_49714952_67062916-99_.jpg
#   inflating: archive/images/images/88_49714953_67064443-43_.jpg
#   inflating: archive/images/images/88_49714954_67070471-99_B.jpg
#   inflating: archive/images/images/88_49714955_67070674-59_B.jpg
#   inflating: archive/images/images/88_49714957_67070678-TC_.jpg
#   inflating: archive/images/images/88_49714958_67071505-99_B.jpg
#   inflating: archive/images/images/88_49714959_67076725-09_.jpg
#   inflating: archive/images/images/88_49714960_67080625-05_.jpg
#   inflating: archive/images/images/88_49714961_67080625-43_.jpg
#   inflating: archive/images/images/88_49714962_67080625-45_.jpg
#   inflating: archive/images/images/88_49714964_67081009-37_.jpg
#   inflating: archive/images/images/88_49714965_67081009-56_.jpg
#   inflating: archive/images/images/88_49714966_67081009-99_.jpg
#   inflating: archive/images/images/88_49714967_67081505-05_.jpg
#   inflating: archive/images/images/88_49714968_67081505-50_.jpg
#   inflating: archive/images/images/88_49714969_67081505-99_B.jpg
#   inflating: archive/images/images/88_49714970_67083266-56_B.jpg
#   inflating: archive/images/images/88_49714971_67084442-06_.jpg
#   inflating: archive/images/images/88_49714972_67084444-56_.jpg
#   inflating: archive/images/images/88_49714974_67094441-43_.jpg
#   inflating: archive/images/images/88_49715038_67012533-50_B.jpg
#   inflating: archive/images/images/88_49715039_67012535-50_.jpg
#   inflating: archive/images/images/88_49715040_67013275-81_.jpg
#   inflating: archive/images/images/88_49715041_67013275-TC_.jpg
#   inflating: archive/images/images/88_49715042_67013697-02_B.jpg
#   inflating: archive/images/images/88_49715043_67022535-70_.jpg
#   inflating: archive/images/images/88_49715044_67032917-TM_B.jpg
#   inflating: archive/images/images/88_49715045_67033687-07_B.jpg
#   inflating: archive/images/images/88_49715046_67033687-56_B.jpg
#   inflating: archive/images/images/88_49715047_67050472-70_B.jpg
#   inflating: archive/images/images/88_49715050_67080472-70_B.jpg
#   inflating: archive/images/images/88_49715051_67083686-56_.jpg
#   inflating: archive/images/images/88_49715052_67084014-TM_B.jpg
#   inflating: archive/images/images/88_49715053_67090676-56_.jpg
#   inflating: archive/images/images/88_49715054_67090676-99_.jpg
#   inflating: archive/images/images/88_49715055_67094444-TM_B.jpg
#   inflating: archive/images/images/88_49715131_67000477-43_.jpg
#   inflating: archive/images/images/88_49715132_67000478-52_.jpg
#   inflating: archive/images/images/88_49715133_67000479-44_.jpg
#   inflating: archive/images/images/88_49715134_67000479-54_.jpg
#   inflating: archive/images/images/88_49715135_67000480-70_.jpg
#   inflating: archive/images/images/88_49715136_67000481-70_.jpg
#   inflating: archive/images/images/88_49715137_67000482-70_.jpg
#   inflating: archive/images/images/88_49715138_67000483-52_.jpg
#   inflating: archive/images/images/88_49715139_67000484-43_.jpg
#   inflating: archive/images/images/88_49715140_67000485-70_.jpg
#   inflating: archive/images/images/88_49715141_67000684-01_.jpg
#   inflating: archive/images/images/88_49715143_67000684-85_B.jpg
#   inflating: archive/images/images/88_49715144_67000684-TC_.jpg
#   inflating: archive/images/images/88_49715145_67000684-TN_B.jpg
#   inflating: archive/images/images/88_49715146_67001013-01_B.jpg
#   inflating: archive/images/images/88_49715147_67001013-TC_B.jpg
#   inflating: archive/images/images/88_49715148_67001013-TG_B.jpg
#   inflating: archive/images/images/88_49715149_67003705-02_B.jpg
#   inflating: archive/images/images/88_49715150_67003707-50_B.jpg
#   inflating: archive/images/images/88_49715151_67003707-56_.jpg
#   inflating: archive/images/images/88_49715153_67010476-56_.jpg
#   inflating: archive/images/images/88_49715154_67014774-PL_.jpg
#   inflating: archive/images/images/88_49715155_67014776-02_B.jpg
#   inflating: archive/images/images/88_49715156_67014777-85_.jpg
#   inflating: archive/images/images/88_49715164_67020474-70_.jpg
#   inflating: archive/images/images/88_49715165_67020475-70_.jpg
#   inflating: archive/images/images/88_49715166_67020476-56_.jpg
#   inflating: archive/images/images/88_49715167_67020675-02_B.jpg
#   inflating: archive/images/images/88_49715168_67023264-50_.jpg
#   inflating: archive/images/images/88_49715171_67030474-43_.jpg
#   inflating: archive/images/images/88_49715172_67030475-56_.jpg
#   inflating: archive/images/images/88_49715173_67030680-50_B.jpg
#   inflating: archive/images/images/88_49715174_67030680-56_B.jpg
#   inflating: archive/images/images/88_49715175_67030680-85_B.jpg
#   inflating: archive/images/images/88_49715176_67030680-95_B.jpg
#   inflating: archive/images/images/88_49715177_67032919-52_.jpg
#   inflating: archive/images/images/88_49715178_67040473-99_.jpg
#   inflating: archive/images/images/88_49715179_67042918-95_.jpg
#   inflating: archive/images/images/88_49715180_67043687-05_.jpg
#   inflating: archive/images/images/88_49715181_67043687-85_.jpg
#   inflating: archive/images/images/88_49715182_67044771-OR_.jpg
#   inflating: archive/images/images/88_49715183_67050473-15_.jpg
#   inflating: archive/images/images/88_49715184_67052918-02_.jpg
#   inflating: archive/images/images/88_49715185_67053267-50_.jpg
#   inflating: archive/images/images/88_49715186_67054771-PL_B.jpg
#   inflating: archive/images/images/88_49715187_67060473-15_.jpg
#   inflating: archive/images/images/88_49715188_67060679-56_.jpg
#   inflating: archive/images/images/88_49715189_67061505-01_.jpg
#   inflating: archive/images/images/88_49715190_67061505-TG_B.jpg
#   inflating: archive/images/images/88_49715191_67061505-TM_.jpg
#   inflating: archive/images/images/88_49715192_67061505-TN_.jpg
#   inflating: archive/images/images/88_49715193_67061505-TO_.jpg
#   inflating: archive/images/images/88_49715194_67062532-01_.jpg
#   inflating: archive/images/images/88_49715195_67062918-92_.jpg
#   inflating: archive/images/images/88_49715196_67064015-07_B.jpg
#   inflating: archive/images/images/88_49715197_67070472-37_.jpg
#   inflating: archive/images/images/88_49715198_67070472-99_.jpg
#   inflating: archive/images/images/88_49715199_67070473-56_.jpg
#   inflating: archive/images/images/88_49715200_67071010-05_.jpg
#   inflating: archive/images/images/88_49715201_67073267-TC_B.jpg
#   inflating: archive/images/images/88_49715202_67073687-01_B.jpg
#   inflating: archive/images/images/88_49715203_67073687-TC_B.jpg
#   inflating: archive/images/images/88_49715204_67073687-TG_.jpg
#   inflating: archive/images/images/88_49715205_67074770-OR_B.jpg
#   inflating: archive/images/images/88_49715206_67080678-85_.jpg
#   inflating: archive/images/images/88_49715207_67083263-02_B.jpg
#   inflating: archive/images/images/88_49715208_67084774-52_B.jpg
#   inflating: archive/images/images/88_49715210_67090678-28_B.jpg
#   inflating: archive/images/images/88_49715211_67090679-56_.jpg
#   inflating: archive/images/images/88_49715212_67093686-07_B.jpg
#   inflating: archive/images/images/88_49715213_67094014-52_.jpg
#   inflating: archive/images/images/88_49715214_67094014-85_.jpg
#   inflating: archive/images/images/88_49715215_67094773-87_.jpg
#   inflating: archive/images/images/88_49715303_67000685-TM_.jpg
#   inflating: archive/images/images/88_49715304_67000686-TN_.jpg
#   inflating: archive/images/images/88_49715305_67000688-01_.jpg
#   inflating: archive/images/images/88_49715306_67000689-TN_.jpg
#   inflating: archive/images/images/88_49715307_67000690-TN_.jpg
#   inflating: archive/images/images/88_49715308_67000691-TO_.jpg
#   inflating: archive/images/images/88_49715320_67005144-99_.jpg
#   inflating: archive/images/images/88_49715321_67005145-PL_.jpg
#   inflating: archive/images/images/88_49715322_67005146-99_.jpg
#   inflating: archive/images/images/88_49715324_67005148-OR_.jpg
#   inflating: archive/images/images/88_49715325_67005149-OR_.jpg
#   inflating: archive/images/images/88_49715326_67005150-OR_.jpg
#   inflating: archive/images/images/88_49715328_67010461-06_.jpg
#   inflating: archive/images/images/88_49715329_67010677-02_.jpg
#   inflating: archive/images/images/88_49715330_67010677-68_B.jpg
#   inflating: archive/images/images/88_49715331_67010687-TM_.jpg
#   inflating: archive/images/images/88_49715332_67013276-TC_.jpg
#   inflating: archive/images/images/88_49715333_67014448-85_B.jpg
#   inflating: archive/images/images/88_49715335_67020467-05_.jpg
#   inflating: archive/images/images/88_49715336_67020467-37_.jpg
#   inflating: archive/images/images/88_49715338_67023688-05_.jpg
#   inflating: archive/images/images/88_49715339_67023689-05_B.jpg
#   inflating: archive/images/images/88_49715342_67033688-16_.jpg
#   inflating: archive/images/images/88_49715343_67033689-56_.jpg
#   inflating: archive/images/images/88_49715344_67034446-08_B.jpg
#   inflating: archive/images/images/88_49715345_67034447-56_B.jpg
#   inflating: archive/images/images/88_49715346_67034448-01_.jpg
#   inflating: archive/images/images/88_49715347_67034448-50_.jpg
#   inflating: archive/images/images/88_49715348_67034448-52_.jpg
#   inflating: archive/images/images/88_49715354_67040677-09_.jpg
#   inflating: archive/images/images/88_49715355_67043688-01_B.jpg
#   inflating: archive/images/images/88_49715356_67044447-08_.jpg
#   inflating: archive/images/images/88_49715359_67053687-02_B.jpg
#   inflating: archive/images/images/88_49715362_67055722-TC_B.jpg
#   inflating: archive/images/images/88_49715363_67060680-TM_B.jpg
#   inflating: archive/images/images/88_49715364_67063687-56_B.jpg
#   inflating: archive/images/images/88_49715365_67064012-02_.jpg
#   inflating: archive/images/images/88_49715366_67064012-37_.jpg
#   inflating: archive/images/images/88_49715367_67064770-85_B.jpg
#   inflating: archive/images/images/88_49715371_67065722-TC_B.jpg
#   inflating: archive/images/images/88_49715372_67070672-02_B.jpg
#   inflating: archive/images/images/88_49715374_67073266-09_.jpg
#   inflating: archive/images/images/88_49715379_67080473-TN_.jpg
#   inflating: archive/images/images/88_49715380_67080676-02_B.jpg
#   inflating: archive/images/images/88_49715381_67080676-68_B.jpg
#   inflating: archive/images/images/88_49715382_67083687-TO_.jpg
#   inflating: archive/images/images/88_49715383_67084775-05_.jpg
#   inflating: archive/images/images/88_49715384_67084776-01_B.jpg
#   inflating: archive/images/images/88_49715386_67093687-16_B.jpg
#   inflating: archive/images/images/88_49715387_67094774-52_B.jpg
#   inflating: archive/images/images/88_49715388_67094775-05_.jpg
#   inflating: archive/images/images/88_49715389_67094776-01_B.jpg
#   inflating: archive/images/images/88_49715473_67060666-69_.jpg
#   inflating: archive/images/images/88_49715474_67060666-99_.jpg
#   inflating: archive/images/images/88_49715475_67062533-05_B.jpg
#   inflating: archive/images/images/88_49715476_67063267-43_.jpg
#   inflating: archive/images/images/88_49715477_67072532-50_B.jpg
#   inflating: archive/images/images/88_49715507_67003277-50_.jpg
#   inflating: archive/images/images/88_49715508_67003278-82_.jpg
#   inflating: archive/images/images/88_49715509_67003279-56_.jpg
#   inflating: archive/images/images/88_49715510_67003713-02_.jpg
#   inflating: archive/images/images/88_49715512_67006317-01_.jpg
#   inflating: archive/images/images/88_49715513_67006317-43_.jpg
#   inflating: archive/images/images/88_49715515_67006318-50_.jpg
#   inflating: archive/images/images/88_49715519_67010478-56_.jpg
#   inflating: archive/images/images/88_49715520_67020477-70_.jpg
#   inflating: archive/images/images/88_49715522_67022532-52_.jpg
#   inflating: archive/images/images/88_49715523_67022918-82_B.jpg
#   inflating: archive/images/images/88_49715524_67022919-02_B.jpg
#   inflating: archive/images/images/88_49715526_67040670-99_.jpg
#   inflating: archive/images/images/88_49715532_67082918-56_B.jpg
#   inflating: archive/images/images/88_49715533_67092917-50_B.jpg
#   inflating: archive/images/images/88_49715628_67003275-56_.jpg
#   inflating: archive/images/images/88_49715629_67003276-53_.jpg
#   inflating: archive/images/images/88_49715630_67013274-53_.jpg
#   inflating: archive/images/images/88_49715631_67022920-52_B.jpg
#   inflating: archive/images/images/88_49715632_67022920-81_B.jpg
#   inflating: archive/images/images/88_49715633_67022920-91_B.jpg
#   inflating: archive/images/images/88_49715634_67023270-99_.jpg
#   inflating: archive/images/images/88_49715635_67032918-TN_.jpg
#   inflating: archive/images/images/88_49715636_67033265-85_.jpg
#   inflating: archive/images/images/88_49715637_67050680-32_.jpg
#   inflating: archive/images/images/88_49715638_67052919-52_B.jpg
#   inflating: archive/images/images/88_49715639_67052919-81_B.jpg
#   inflating: archive/images/images/88_49715640_67052919-91_B.jpg
#   inflating: archive/images/images/88_49715653_67060474-70_.jpg
#   inflating: archive/images/images/88_49715666_67064445-85_B.jpg
#   inflating: archive/images/images/88_49715667_67070474-70_.jpg
#   inflating: archive/images/images/88_49715674_67082532-43_B.jpg
#   inflating: archive/images/images/88_49715675_67082532-81_B.jpg
#   inflating: archive/images/images/88_49715676_67082917-TM_.jpg
#   inflating: archive/images/images/88_49715678_67092527-68_.jpg
#   inflating: archive/images/images/88_49715679_67092532-02_B.jpg
#   inflating: archive/images/images/88_49715680_67092532-43_B.jpg
#   inflating: archive/images/images/88_49715681_67092532-81_B.jpg
#   inflating: archive/images/images/88_49715769_67024449-43_.jpg
#   inflating: archive/images/images/88_49715770_67024449-50_.jpg
#   inflating: archive/images/images/88_49715771_67024449-52_.jpg
#   inflating: archive/images/images/88_49715772_67024449-56_.jpg
#   inflating: archive/images/images/88_49715773_67024450-01_.jpg
#   inflating: archive/images/images/88_49715774_67024450-43_.jpg
#   inflating: archive/images/images/88_49715775_67024450-50_.jpg
#   inflating: archive/images/images/88_49715776_67024450-99_.jpg
#   inflating: archive/images/images/88_49715778_67059404-99_.jpg
#   inflating: archive/images/images/88_49715780_67060678-56_.jpg
#   inflating: archive/images/images/88_49715781_67060678-94_.jpg
#   inflating: archive/images/images/88_49715782_67064444-56_.jpg
#   inflating: archive/images/images/88_49715783_67069218-99_.jpg
#   inflating: archive/images/images/88_49715784_67070680-36_B.jpg
#   inflating: archive/images/images/88_49715785_67074444-56_.jpg
#   inflating: archive/images/images/88_49715787_67082529-88_.jpg
#   inflating: archive/images/images/88_49715788_67084443-08_.jpg
#   inflating: archive/images/images/88_49715791_67094443-08_.jpg
#   inflating: archive/images/images/88_49715888_67000662-51_.jpg
#   inflating: archive/images/images/88_49715889_67010477-70_.jpg
#   inflating: archive/images/images/88_49715890_67010477-99_.jpg
#   inflating: archive/images/images/88_49715891_67010656-05_.jpg
#   inflating: archive/images/images/88_49715892_67010656-40_.jpg
#   inflating: archive/images/images/88_49715893_67014451-37_.jpg
#   inflating: archive/images/images/88_49715894_67015979-09_.jpg
#   inflating: archive/images/images/88_49715895_67015979-92_.jpg
#   inflating: archive/images/images/88_49715896_67015981-09_.jpg
#   inflating: archive/images/images/88_49715897_67015981-78_.jpg
#   inflating: archive/images/images/88_49715899_67032534-08_.jpg
#   inflating: archive/images/images/88_49715900_67032534-40_.jpg
#   inflating: archive/images/images/88_49715901_67034442-06_.jpg
#   inflating: archive/images/images/88_49715902_67034442-35_.jpg
#   inflating: archive/images/images/88_49715903_67034442-56_.jpg
#   inflating: archive/images/images/88_49715905_67040474-70_.jpg
#   inflating: archive/images/images/88_49715906_67040474-99_.jpg
#   inflating: archive/images/images/88_49715909_67045978-07_.jpg
#   inflating: archive/images/images/88_49715910_67045978-CG_.jpg
#   inflating: archive/images/images/88_49715911_67054439-55_.jpg
#   inflating: archive/images/images/88_49715919_67074438-08_.jpg
#   inflating: archive/images/images/88_49715920_67074438-56_.jpg
#   inflating: archive/images/images/88_49715921_67076724-31_.jpg
#   inflating: archive/images/images/88_49715922_67076724-56_.jpg
#   inflating: archive/images/images/88_49715924_67080679-30_.jpg
#   inflating: archive/images/images/88_49715925_67090473-70_.jpg
#   inflating: archive/images/images/88_49715926_67090473-99_.jpg
#   inflating: archive/images/images/88_49715928_67090644-05_.jpg
#   inflating: archive/images/images/88_49715929_67095977-37_.jpg
#   inflating: archive/images/images/88_49715930_67095977-56_.jpg
#   inflating: archive/images/images/88_49716101_67012537-TM_.jpg
#   inflating: archive/images/images/88_49716102_67012538-05_.jpg
#   inflating: archive/images/images/88_49716103_67030478-TM_.jpg
#   inflating: archive/images/images/88_49716104_67033690-56_B.jpg
#   inflating: archive/images/images/88_49716105_67034449-85_.jpg
#   inflating: archive/images/images/88_49716106_67034450-08_B.jpg
#   inflating: archive/images/images/88_49716107_67036726-05_.jpg
#   inflating: archive/images/images/88_49716108_67040477-02_.jpg
#   inflating: archive/images/images/88_49716109_67042535-TM_.jpg
#   inflating: archive/images/images/88_49716113_67052535-70_.jpg
#   inflating: archive/images/images/88_49716114_67060476-TN_.jpg
#   inflating: archive/images/images/88_49716115_67060662-48_B.jpg
#   inflating: archive/images/images/88_49716116_67060662-56_B.jpg
#   inflating: archive/images/images/88_49716117_67070476-56_.jpg
#   inflating: archive/images/images/88_49716118_67075722-02_B.jpg
#   inflating: archive/images/images/88_49716119_67075722-05_.jpg
#   inflating: archive/images/images/88_49716120_67075722-85_.jpg
#   inflating: archive/images/images/88_49716121_67083688-TM_B.jpg
#   inflating: archive/images/images/88_49716123_67085137-05_.jpg
#   inflating: archive/images/images/88_49716124_67085139-01_.jpg
#   inflating: archive/images/images/88_49716125_67092534-01_.jpg
#   inflating: archive/images/images/88_49716127_67094016-06_.jpg
#   inflating: archive/images/images/88_49716128_67094016-37_.jpg
#   inflating: archive/images/images/88_49716129_67096312-02_.jpg
#   inflating: archive/images/images/88_49716255_67034440-08_.jpg
#   inflating: archive/images/images/88_49716256_67034440-39_.jpg
#   inflating: archive/images/images/88_49716257_67034440-56_.jpg
#   inflating: archive/images/images/88_49716258_67034440-92_.jpg
#   inflating: archive/images/images/88_49716259_67034440-99_.jpg
#   inflating: archive/images/images/88_49716260_67034441-92_.jpg
#   inflating: archive/images/images/88_49716261_67034441-99_.jpg
#   inflating: archive/images/images/88_49716262_67042912-50_.jpg
#   inflating: archive/images/images/88_49716263_67042912-99_.jpg
#   inflating: archive/images/images/88_49716267_67054447-70_.jpg
#   inflating: archive/images/images/88_49716268_67056725-56_.jpg
#   inflating: archive/images/images/88_49716269_67066310-07_.jpg
#   inflating: archive/images/images/88_49716270_67066310-56_.jpg
#   inflating: archive/images/images/88_49716271_67074446-05_.jpg
#   inflating: archive/images/images/88_49716272_67076310-37_.jpg
#   inflating: archive/images/images/88_49716273_67094778-PL_.jpg
#   inflating: archive/images/images/88_49716343_67000462-02_.jpg
#   inflating: archive/images/images/88_49716344_67000462-37_.jpg
#   inflating: archive/images/images/88_49716351_67011012-02_B.jpg
#   inflating: archive/images/images/88_49716352_67011012-85_B.jpg
#   inflating: archive/images/images/88_49716353_67011013-02_B.jpg
#   inflating: archive/images/images/88_49716355_67012924-01_.jpg
#   inflating: archive/images/images/88_49716356_67015980-05_.jpg
#   inflating: archive/images/images/88_49716357_67015982-31_.jpg
#   inflating: archive/images/images/88_49716358_67015982-56_.jpg
#   inflating: archive/images/images/88_49716361_67023272-99_.jpg
#   inflating: archive/images/images/88_49716368_67036311-07_.jpg
#   inflating: archive/images/images/88_49716369_67036311-33_.jpg
#   inflating: archive/images/images/88_49716370_67036311-37_.jpg
#   inflating: archive/images/images/88_49716375_67061011-02_B.jpg
#   inflating: archive/images/images/88_49716376_67061011-50_B.jpg
#   inflating: archive/images/images/88_49716384_67072918-37_.jpg
#   inflating: archive/images/images/88_49716389_67081010-02_B.jpg
#   inflating: archive/images/images/88_49716391_67084017-85_B.jpg
#   inflating: archive/images/images/88_49716392_67092533-56_B.jpg
#   inflating: archive/images/images/88_49716395_67096311-01_.jpg
#   inflating: archive/images/images/88_49716396_67096311-12_.jpg
#   inflating: archive/images/images/88_49716397_67096311-25_.jpg
#   inflating: archive/images/images/88_49716398_67096311-30_.jpg
#   inflating: archive/images/images/88_49716399_67096311-35_.jpg
#   inflating: archive/images/images/88_49716400_67096311-37_.jpg
#   inflating: archive/images/images/88_49716401_67096311-45_.jpg
#   inflating: archive/images/images/88_49716402_67096311-50_.jpg
#   inflating: archive/images/images/88_49716403_67096311-95_.jpg
#   inflating: archive/images/images/88_49716491_67000464-37_.jpg
#   inflating: archive/images/images/88_49716492_67000464-99_.jpg
#   inflating: archive/images/images/88_49716493_67000683-02_.jpg
#   inflating: archive/images/images/88_49716495_67015980-56_.jpg
#   inflating: archive/images/images/88_49716497_67030460-07_.jpg
#   inflating: archive/images/images/88_49716498_67030460-92_.jpg
#   inflating: archive/images/images/88_49716499_67032535-02_B.jpg
#   inflating: archive/images/images/88_49716501_67042919-52_.jpg
#   inflating: archive/images/images/88_49716502_67044448-70_.jpg
#   inflating: archive/images/images/88_49716503_67044448-99_.jpg
#   inflating: archive/images/images/88_49716504_67050461-08_.jpg
#   inflating: archive/images/images/88_49716505_67050461-99_.jpg
#   inflating: archive/images/images/88_49716506_67052534-02_B.jpg
#   inflating: archive/images/images/88_49716507_67060460-30_.jpg
#   inflating: archive/images/images/88_49716508_67060460-99_.jpg
#   inflating: archive/images/images/88_49716509_67060475-30_.jpg
#   inflating: archive/images/images/88_49716510_67062534-56_B.jpg
#   inflating: archive/images/images/88_49716511_67072534-02_B.jpg
#   inflating: archive/images/images/88_49716512_67080474-30_.jpg
#   inflating: archive/images/images/88_49716513_67090474-92_.jpg
#   inflating: archive/images/images/88_49716621_67000659-43_.jpg
#   inflating: archive/images/images/88_49716622_67000683-TC_.jpg
#   inflating: archive/images/images/88_49716623_67010658-96_.jpg
#   inflating: archive/images/images/88_49716624_67016732-06_.jpg
#   inflating: archive/images/images/88_49716625_67030659-56_B.jpg
#   inflating: archive/images/images/88_49716626_67030659-99_B.jpg
#   inflating: archive/images/images/88_49716627_67050470-95_.jpg
#   inflating: archive/images/images/88_49716628_67052917-37_.jpg
#   inflating: archive/images/images/88_49716630_67062917-95_.jpg
#   inflating: archive/images/images/88_49716631_67072917-37_.jpg
#   inflating: archive/images/images/88_49716632_67083261-37_.jpg
#   inflating: archive/images/images/88_49716634_67090476-37_.jpg
#   inflating: archive/images/images/88_49716763_67013273-56_.jpg
#   inflating: archive/images/images/88_49716764_67016315-35_.jpg
#   inflating: archive/images/images/88_49716765_67020480-01_.jpg
#   inflating: archive/images/images/88_49716766_67022921-56_.jpg
#   inflating: archive/images/images/88_49716767_67022922-56_.jpg
#   inflating: archive/images/images/88_49716768_67030479-01_.jpg
#   inflating: archive/images/images/88_49716770_67040478-07_.jpg
#   inflating: archive/images/images/88_49716771_67040478-99_.jpg
#   inflating: archive/images/images/88_49716773_67050477-85_.jpg
#   inflating: archive/images/images/88_49716774_67050678-91_.jpg
#   inflating: archive/images/images/88_49716775_67060478-01_.jpg
#   inflating: archive/images/images/88_49716779_67080477-TO_.jpg
#   inflating: archive/images/images/88_49716780_67090477-01_.jpg
#   inflating: archive/images/images/88_49716781_67090681-68_.jpg
#   inflating: archive/images/images/88_49716782_67094018-52_.jpg
#   inflating: archive/images/images/88_49716813_67016727-02_.jpg
#   inflating: archive/images/images/88_49716814_67016727-56_.jpg
#   inflating: archive/images/images/88_49716815_67016728-08_.jpg
#   inflating: archive/images/images/88_49716816_67016729-06_.jpg
#   inflating: archive/images/images/88_49716817_67016729-56_.jpg
#   inflating: archive/images/images/88_49716818_67016730-08_.jpg
#   inflating: archive/images/images/88_49716819_67016730-57_.jpg
#   inflating: archive/images/images/88_49716820_67016731-30_.jpg
#   inflating: archive/images/images/88_49716821_67023691-02_B.jpg
#   inflating: archive/images/images/88_49716822_67026726-37_.jpg
#   inflating: archive/images/images/88_49716823_67032916-95_.jpg
#   inflating: archive/images/images/88_49716824_67035978-05_.jpg
#   inflating: archive/images/images/88_49716825_67035978-31_.jpg
#   inflating: archive/images/images/88_49716826_67035978-37_.jpg
#   inflating: archive/images/images/88_49716827_67035978-56_.jpg
#   inflating: archive/images/images/88_49716828_67035978-78_.jpg
#   inflating: archive/images/images/88_49716829_67046725-08_.jpg
#   inflating: archive/images/images/88_49716830_67046725-56_.jpg
#   inflating: archive/images/images/88_49716832_67056724-10_.jpg
#   inflating: archive/images/images/88_49716836_67085977-02_.jpg
#   inflating: archive/images/images/88_49716837_67085977-08_.jpg
#   inflating: archive/images/images/88_49716838_67085977-31_.jpg
#   inflating: archive/images/images/88_49716839_67085977-56_.jpg
#   inflating: archive/images/images/88_49716840_67092535-91_B.jpg
#   inflating: archive/images/images/88_49717007_67001014-02_B.jpg
#   inflating: archive/images/images/88_49717008_67006317-99_.jpg
#   inflating: archive/images/images/88_49717009_67010482-05_.jpg
#   inflating: archive/images/images/88_49717010_67012540-56_B.jpg
#   inflating: archive/images/images/88_49717012_67023690-02_B.jpg
#   inflating: archive/images/images/88_49717014_67030480-56_.jpg
#   inflating: archive/images/images/88_49717015_67030682-TM_.jpg
#   inflating: archive/images/images/88_49717016_67035983-08_.jpg
#   inflating: archive/images/images/88_49717017_67035983-50_.jpg
#   inflating: archive/images/images/88_49717019_67036729-56_.jpg
#   inflating: archive/images/images/88_49717021_67040681-05_.jpg
#   inflating: archive/images/images/88_49717022_67042537-02_B.jpg
#   inflating: archive/images/images/88_49717023_67044449-PL_.jpg
#   inflating: archive/images/images/88_49717025_67044779-OR_.jpg
#   inflating: archive/images/images/88_49717026_67045982-01_.jpg
#   inflating: archive/images/images/88_49717027_67045982-30_.jpg
#   inflating: archive/images/images/88_49717028_67045982-37_.jpg
#   inflating: archive/images/images/88_49717029_67045982-56_.jpg
#   inflating: archive/images/images/88_49717030_67045982-78_.jpg
#   inflating: archive/images/images/88_49717031_67050474-52_.jpg
#   inflating: archive/images/images/88_49717033_67050478-56_.jpg
#   inflating: archive/images/images/88_49717035_67054779-OR_.jpg
#   inflating: archive/images/images/88_49717036_67055981-07_.jpg
#   inflating: archive/images/images/88_49717037_67063688-56_.jpg
#   inflating: archive/images/images/88_49717038_67066724-01_.jpg
#   inflating: archive/images/images/88_49717039_67066724-05_.jpg
# ...
#   inflating: archive/images/images/88_49734556_67008663-99_.jpg
#   inflating: archive/images/images/88_49734557_67009239-88_.jpg
#   inflating: archive/images/images/88_49734558_67009406-05_.jpg
#   inflating: archive/images/images/88_49734559_67017148-09_.jpg
#   inflating: archive/images/images/88_49734560_67018658-83_.jpg
#   inflating: archive/images/images/88_49734561_67018659-50_.jpg
#   inflating: archive/images/images/88_49734562_67018660-99_.jpg
#   inflating: archive/images/images/88_49734563_67018661-99_.jpg
#   inflating: archive/images/images/88_49734564_67026351-06_.jpg
#   inflating: archive/images/images/88_49734565_67027148-50_.jpg
#   inflating: archive/images/images/88_49734566_67028658-99_.jpg
#   inflating: archive/images/images/88_49734567_67029405-05_.jpg
#   inflating: archive/images/images/88_49734569_67035758-50_.jpg
#   inflating: archive/images/images/88_49734570_67036755-50_.jpg
#   inflating: archive/images/images/88_49734571_67037148-01_.jpg
#   inflating: archive/images/images/88_49734572_67037927-92_.jpg
#   inflating: archive/images/images/88_49734573_67038657-05_.jpg
#   inflating: archive/images/images/88_49734574_67044793-99_.jpg
#   inflating: archive/images/images/88_49734575_67046349-81_.jpg
#   inflating: archive/images/images/88_49734579_67047926-05_.jpg
#   inflating: archive/images/images/88_49734580_67048656-02_.jpg
#   inflating: archive/images/images/88_49734581_67049231-20_.jpg
#   inflating: archive/images/images/88_49734582_67054793-99_.jpg
#   inflating: archive/images/images/88_49734584_67057147-99_.jpg
#   inflating: archive/images/images/88_49734585_67057926-91_.jpg
#   inflating: archive/images/images/88_49734586_67059230-21_B.jpg
#   inflating: archive/images/images/88_49734587_67064793-52_.jpg
#   inflating: archive/images/images/88_49734588_67064793-99_.jpg
#   inflating: archive/images/images/88_49734592_67067147-52_.jpg
#   inflating: archive/images/images/88_49734593_67067925-05_.jpg
#   inflating: archive/images/images/88_49734594_67067926-92_.jpg
#   inflating: archive/images/images/88_49734595_67069230-21_.jpg
#   inflating: archive/images/images/88_49734596_67076348-99_.jpg
#   inflating: archive/images/images/88_49734597_67077925-02_.jpg
#   inflating: archive/images/images/88_49734599_67085155-02_.jpg
#   inflating: archive/images/images/88_49734600_67086754-50_.jpg
#   inflating: archive/images/images/88_49734601_67087147-99_.jpg
#   inflating: archive/images/images/88_49734602_67087925-02_.jpg
#   inflating: archive/images/images/88_49734603_67088655-50_.jpg
#   inflating: archive/images/images/88_49734604_67096348-81_.jpg
#   inflating: archive/images/images/88_49734606_67097925-05_.jpg
#   inflating: archive/images/images/88_49734803_67005761-05_.jpg
#   inflating: archive/images/images/88_49734805_67007149-05_.jpg
#   inflating: archive/images/images/88_49734806_67008660-08_.jpg
#   inflating: archive/images/images/88_49734807_67008660-83_.jpg
#   inflating: archive/images/images/88_49734808_67008661-85_.jpg
#   inflating: archive/images/images/88_49734809_67008664-TS_.jpg
#   inflating: archive/images/images/88_49734812_67018662-99_.jpg
#   inflating: archive/images/images/88_49734813_67025760-02_.jpg
#   inflating: archive/images/images/88_49734818_67027149-99_.jpg
#   inflating: archive/images/images/88_49734820_67028660-90_.jpg
#   inflating: archive/images/images/88_49734821_67028661-09_.jpg
#   inflating: archive/images/images/88_49734825_67037928-87_.jpg
#   inflating: archive/images/images/88_49734826_67038658-05_.jpg
#   inflating: archive/images/images/88_49734827_67038659-05_B.jpg
#   inflating: archive/images/images/88_49734829_67047148-TC_.jpg
#   inflating: archive/images/images/88_49734831_67048657-99_.jpg
#   inflating: archive/images/images/88_49734832_67048658-90_.jpg
#   inflating: archive/images/images/88_49734833_67048659-05_.jpg
#   inflating: archive/images/images/88_49734836_67056349-05_.jpg
#   inflating: archive/images/images/88_49734837_67056749-40_.jpg
#   inflating: archive/images/images/88_49734838_67057148-30_.jpg
#   inflating: archive/images/images/88_49734839_67057927-08_.jpg
#   inflating: archive/images/images/88_49734840_67058656-TS_.jpg
#   inflating: archive/images/images/88_49734841_67058657-05_.jpg
#   inflating: archive/images/images/88_49734843_67067927-05_.jpg
#   inflating: archive/images/images/88_49734844_67068656-05_.jpg
#   inflating: archive/images/images/88_49734846_67077147-02_.jpg
#   inflating: archive/images/images/88_49734849_67077927-05_.jpg
#   inflating: archive/images/images/88_49734850_67078656-05_.jpg
#   inflating: archive/images/images/88_49734851_67079054-TM_.jpg
#   inflating: archive/images/images/88_49734852_67085759-05_.jpg
#   inflating: archive/images/images/88_49734853_67085759-99_.jpg
#   inflating: archive/images/images/88_49734857_67087148-43_.jpg
#   inflating: archive/images/images/88_49734858_67087926-02_.jpg
#   inflating: archive/images/images/88_49734859_67088656-99_.jpg
#   inflating: archive/images/images/88_49734860_67097147-91_.jpg
#   inflating: archive/images/images/88_49734861_67097148-99_.jpg
#   inflating: archive/images/images/88_49734862_67098655-TM_.jpg
#   inflating: archive/images/images/88_49735128_67015759-88_.jpg
#   inflating: archive/images/images/88_49735130_67027929-05_.jpg
#   inflating: archive/images/images/88_49735131_67028280-45_.jpg
#   inflating: archive/images/images/88_49735132_67037149-52_.jpg
#   inflating: archive/images/images/88_49735133_67047149-05_.jpg
#   inflating: archive/images/images/88_49735134_67065757-88_.jpg
#   inflating: archive/images/images/88_49735135_67068279-45_.jpg
#   inflating: archive/images/images/88_49735137_67086055-02_.jpg
#   inflating: archive/images/images/88_49735138_67086055-99_.jpg
#   inflating: archive/images/images/88_49735139_67088279-20_.jpg
#   inflating: archive/images/images/88_49735303_67009240-21_.jpg
#   inflating: archive/images/images/88_49735304_67018281-40_.jpg
#   inflating: archive/images/images/88_49735306_67038280-43_.jpg
#   inflating: archive/images/images/88_49735307_67047722-92_.jpg
#   inflating: archive/images/images/88_49735308_67049232-75_.jpg
#   inflating: archive/images/images/88_49735309_67057719-05_.jpg
#   inflating: archive/images/images/88_49735310_67057720-99_.jpg
#   inflating: archive/images/images/88_49735311_67057721-06_.jpg
#   inflating: archive/images/images/88_49735312_67058651-02_.jpg
#   inflating: archive/images/images/88_49735313_67066349-99_.jpg
#   inflating: archive/images/images/88_49735314_67067719-99_.jpg
#   inflating: archive/images/images/88_49735315_67067720-11_.jpg
#   inflating: archive/images/images/88_49735316_67067721-08_.jpg
#   inflating: archive/images/images/88_49735317_67068657-08_.jpg
#   inflating: archive/images/images/88_49735318_67077719-06_.jpg
#   inflating: archive/images/images/88_49735319_67077720-08_.jpg
#   inflating: archive/images/images/88_49735320_67087719-11_.jpg
#   inflating: archive/images/images/88_49735321_67087927-06_.jpg
#   inflating: archive/images/images/88_49735322_67089230-75_.jpg
#   inflating: archive/images/images/88_49735323_67097718-08_.jpg
#   inflating: archive/images/images/88_49735324_67097927-08_.jpg
#   inflating: archive/images/images/88_49735325_67098279-02_.jpg
#   inflating: archive/images/images/88_49735326_67098656-06_B.jpg
#   inflating: archive/images/images/88_49735461_67027930-DC_.jpg
#   inflating: archive/images/images/88_49735465_67077721-02_.jpg
#   inflating: archive/images/images/88_49735565_67009241-52_.jpg
#   inflating: archive/images/images/88_49735568_67057928-05_.jpg
#   inflating: archive/images/images/88_49735570_67076755-08_.jpg
#   inflating: archive/images/images/88_49735571_67076755-43_.jpg
#   inflating: archive/images/images/88_49735572_67076755-81_.jpg
#   inflating: archive/images/images/88_49735573_67087718-30_.jpg
#   inflating: archive/images/images/88_49735574_67097926-08_.jpg
#   inflating: archive/images/images/88_49735575_67099230-52_.jpg
#   inflating: archive/images/images/88_49735784_67006354-06_.jpg
#   inflating: archive/images/images/88_49735785_67006354-99_.jpg
#   inflating: archive/images/images/88_49735786_67007150-43_.jpg
#   inflating: archive/images/images/88_49735787_67067928-08_.jpg
#   inflating: archive/images/images/88_49735945_67017149-31_.jpg
#   inflating: archive/images/images/88_49735946_67047928-05_.jpg
#   inflating: archive/images/images/88_49735947_67087928-81_.jpg
#   inflating: archive/images/images/88_49736181_67017150-30_.jpg
#   inflating: archive/images/images/88_49736182_67057926-30_.jpg
#   inflating: archive/images/images/88_49736183_67058658-02_.jpg
#   inflating: archive/images/images/88_49736185_67059231-02_.jpg
#   inflating: archive/images/images/88_49736186_67059232-TM_.jpg
#   inflating: archive/images/images/88_49736187_67077928-08_.jpg
#   inflating: archive/images/images/88_49736188_67078657-52_.jpg
#   inflating: archive/images/images/88_49736189_67088657-52_.jpg
#   inflating: archive/images/images/88_49736190_67098657-52_.jpg
#   inflating: archive/images/images/88_49736540_67016756-05_.jpg
#   inflating: archive/images/images/88_49736541_67037129-05_.jpg
#   inflating: archive/images/images/88_49736542_67039233-99_.jpg
#   inflating: archive/images/images/88_49736543_67039234-11_.jpg
#   inflating: archive/images/images/88_49736544_67039235-20_.jpg
#   inflating: archive/images/images/88_49736545_67049233-99_.jpg
#   inflating: archive/images/images/88_49736546_67049234-14_.jpg
#   inflating: archive/images/images/88_49736547_67069231-01_.jpg
#   inflating: archive/images/images/88_49736548_67069232-11_.jpg
#   inflating: archive/images/images/88_49736549_67079231-01_.jpg
#   inflating: archive/images/images/88_49736550_67079232-14_B.jpg
#   inflating: archive/images/images/88_49736557_67086755-56_.jpg
#   inflating: archive/images/images/88_49737139_67009242-52_.jpg
#   inflating: archive/images/images/88_49737288_67047929-08_.jpg
#   inflating: archive/images/images/88_49737289_67087142-37_.jpg
#   inflating: archive/images/images/88_49737417_67026756-02_B.jpg
#   inflating: archive/images/images/88_49737418_67036756-56_.jpg
#   inflating: archive/images/images/88_49737419_67036756-86_.jpg
#   inflating: archive/images/images/88_49737690_67009245-70_.jpg
#   inflating: archive/images/images/88_49737949_67009246-14_.jpg
#   inflating: archive/images/images/88_49737950_67009247-81_.jpg
#   inflating: archive/images/images/88_49737951_67009248-05_.jpg
#   inflating: archive/images/images/88_49737952_67009249-05_.jpg
#   inflating: archive/images/images/88_49737953_67009250-14_.jpg
#   inflating: archive/images/images/88_49737954_67009251-45_.jpg
#   inflating: archive/images/images/88_49737955_67009251-99_.jpg
#   inflating: archive/images/images/88_49737956_67017937-10_.jpg
#   inflating: archive/images/images/88_49737957_67017937-31_.jpg
#   inflating: archive/images/images/88_49737959_67028662-81_.jpg
#   inflating: archive/images/images/88_49737960_67028662-99_.jpg
#   inflating: archive/images/images/88_49737961_67057929-05_.jpg
#   inflating: archive/images/images/88_49737962_67057929-38_.jpg
#   inflating: archive/images/images/88_49737965_67077929-99_.jpg
#   inflating: archive/images/images/88_49737966_67079233-PL_.jpg
#   inflating: archive/images/images/88_49738139_67009254-46_.jpg
#   inflating: archive/images/images/88_49738140_67027931-02_.jpg
#   inflating: archive/images/images/88_49738141_67087929-08_.jpg
#   inflating: archive/images/images/88_49738259_67009252-05_.jpg
#   inflating: archive/images/images/88_49738260_67009253-52_.jpg
#   inflating: archive/images/images/88_49738261_67009255-43_.jpg
#   inflating: archive/images/images/88_49738264_67059233-05_.jpg
#   inflating: archive/images/images/88_49738265_67059234-14_.jpg
#   inflating: archive/images/images/88_49738267_67069233-43_.jpg
#   inflating: archive/images/images/88_49738273_67099231-11_.jpg
#   inflating: archive/images/images/88_49738274_67099232-23_.jpg
#   inflating: archive/images/images/88_49738413_67009256-46_.jpg
#   inflating: archive/images/images/88_49738415_67009258-70_.jpg
#   inflating: archive/images/images/88_49738416_67018658-99_.jpg
#   inflating: archive/images/images/88_49738417_67089232-99_.jpg
#   inflating: archive/images/images/88_49738691_67009244-85_.jpg
#   inflating: archive/images/images/88_49738692_67019236-05_.jpg
#   inflating: archive/images/images/88_49738693_67019237-14_.jpg
#   inflating: archive/images/images/88_49738974_67007971-01_.jpg
#   inflating: archive/images/images/88_49738975_67007971-70_.jpg
#   inflating: archive/images/images/88_49738976_67007971-99_.jpg
#   inflating: archive/images/images/88_49738981_67089231-05_.jpg
#   inflating: archive/images/images/88_49739063_67009243-14_.jpg
#   inflating: archive/images/images/88_49739286_67007972-99_.jpg
#   inflating: archive/images/images/88_49739287_67048280-08_.jpg
#   inflating: archive/images/images/88_49739288_67048280-99_.jpg
#   inflating: archive/images/images/88_49739289_67098658-70_.jpg
#   inflating: archive/images/images/88_49739498_67009261-81_.jpg
#   inflating: archive/images/images/88_49739499_67009262-02_.jpg
#   inflating: archive/images/images/88_49740276_67009259-70_.jpg
#   inflating: archive/images/images/88_49740277_67009259-99_.jpg
#   inflating: archive/images/images/88_49740278_67069605-08_.jpg
#   inflating: archive/images/images/88_49740279_67079605-08_.jpg
#   inflating: archive/images/images/88_49740549_67097929-82_B.jpg
#   inflating: archive/images/images/88_49740760_67009260-99_.jpg
#   inflating: archive/images/images/88_49740975_67009265-70_.jpg
#   inflating: archive/images/images/88_49740976_67009266-52_.jpg
#   inflating: archive/images/images/88_49740977_67067929-70_.jpg
#   inflating: archive/images/images/88_49740978_67067929-99_.jpg
#   inflating: archive/images/images/88_49740979_67079234-70_.jpg
#   inflating: archive/images/images/88_49740980_67089234-52_.jpg
#   inflating: archive/images/images/88_49740981_67099233-05_.jpg
#   inflating: archive/images/images/88_49741194_67077929-02_.jpg
#   inflating: archive/images/images/88_49741581_67009264-12_.jpg
#   inflating: archive/images/images/88_49741741_67009257-43_.jpg
#   inflating: archive/images/images/88_49741933_67009267-25_.jpg
#   inflating: archive/images/images/88_49741934_67041015-TO_.jpg
#   inflating: archive/images/images/88_49741935_67051014-TN_.jpg
#   inflating: archive/images/images/88_49742563_67039405-05_.jpg
#   inflating: archive/images/images/88_49742564_67039405-99_.jpg
#   inflating: archive/images/images/88_49742775_67019237-99_.jpg
#   inflating: archive/images/images/88_49742778_67059235-43_.jpg
#   inflating: archive/images/images/88_49742779_67059235-85_.jpg
#   inflating: archive/images/images/88_49742781_67077929-37_.jpg
#   inflating: archive/images/images/88_49742784_67099234-56_.jpg
#   inflating: archive/images/images/88_49742785_67099234-88_.jpg
#   inflating: archive/images/images/88_49743586_67073692-05_.jpg
#   inflating: archive/images/images/88_49743912_67093692-05_.jpg
#   inflating: archive/images/images/88_49745420_67085744-85_.jpg
#   inflating: archive/product_data.csv
#   inflating: archive/sample_submission.csv
#   inflating: archive/test_data.csv
#   inflating: images_sample/images_sample/83_1113943_17047501-41_.jpg
#   inflating: images_sample/images_sample/83_1114014_17010532-91_B.jpg
#   inflating: images_sample/images_sample/83_1114401_17080112-TM_B.jpg
#   inflating: images_sample/images_sample/83_1114536_17090120-20_.jpg
#   inflating: images_sample/images_sample/84_1167821_27009002-43_.jpg
#   inflating: images_sample/images_sample/84_1167830_27095907-03_B.jpg
#   inflating: images_sample/images_sample/86_1205478_47050075-99_B.jpg
#   inflating: images_sample/images_sample/86_1206011_47000804-54_B.jpg

# %% [markdown]
# ### Definint the data loader

# %%
class CustomDataset(Dataset):
    def __init__(self, csv_file, image_dir, transform=None):
        """
        Inicialitza el conjunt de dades personalitzat.

        Args:
            csv_file (str): El camí al fitxer CSV amb les etiquetes.
            image_dir (str): El directori que conté les imatges.
            transform (callable, optional): Transformacions a aplicar a les imatges.
        """
        self.img_labels = pd.read_csv(csv_file)  # Carrega el CSV amb les etiquetes
        self.img_labels['filename'] = self.img_labels['filename'].astype(str)
        self.img_labels = self.img_labels.drop(columns=['cod_modelo_color'])
        self.img_dir = image_dir  # Directori de les imatges
        self.transform = transform  # Transformacions (per exemple, redimensionar, normalitzar)

        # Preparem les etiquetes
        self.label_columns = self.img_labels.columns.difference(['filename'])

        # Codificació de les etiquetes si són categòriques
        self.label_encoders = {}
        for col in self.label_columns:
            le = LabelEncoder()
            self.img_labels[col] = le.fit_transform(self.img_labels[col])  # Codifiquem les etiquetes
            self.label_encoders[col] = le  # Guardem l'encoder per a futures prediccions


    def __len__(self):
        """Retorna la mida total del conjunt de dades."""
        return len(self.img_labels)

    def __getitem__(self, index):
        """
        Obté una imatge i la seva etiqueta corresponent.

        Args:
            index (int): Índex de la imatge i etiqueta a recuperar.

        Returns:
            tuple: (imatge, etiqueta) on l'imatge és un tensor i l'etiqueta és un tensor.
        """
        # Obtenir el camí de la imatge
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[index, 0])  # 'filename' és a la primera columna
        image = read_image(img_path)  # Obrim l'imatge i la convertim a RGB



        # Aplica transformacions si n'hi ha
        if self.transform:
            image = self.transform(image)


        label = self.img_labels.iloc[index,1:]
        label = label.values.astype('int')
        image = image.type(torch.float32)
        return image, label

# %% [markdown]
# ## Training costumization

# %%
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset


# Definir el teu model
model = MangoNet(num_channels=11 * (33 + 1), drop=0.5)
model = model.to('cuda')
# Defineix la funció de pèrdua (per exemple, CrossEntropyLoss per classificació)
criterion = nn.CrossEntropyLoss()

# Definir diferents learning rates per a les capes preentrenades i la nova capa
optimizer = optim.Adam([
    {'params': model.features.parameters(), 'lr': 1e-4},  # LR més petit per a les capes preentrenades
    {'params': model.classifier.parameters(), 'lr': 1e-3}  # LR més gran per a la nova capa
])

# Configuració de l'entrenament


num_epochs = 1
dataset = CustomDataset(csv_file='/content/drive/MyDrive/clean_data.csv', image_dir='/content/archive/images/images', transform=None)
train_loader = DataLoader(dataset, batch_size=64, shuffle=True)

# Entrenament
for epoch in range(num_epochs):
    model.train()  # Mode entrenament
    running_loss = 0.0
    it = 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)  # Envia les dades a la GPU si en tens una

        # Zero gradients
        optimizer.zero_grad()
        it += 1
        # Forward pass
        try:
          outputs = model(inputs)
        except Exception as ex:
          print(ex)
          breakpoint()
        loss = criterion(outputs, labels)
        print(loss.item())

        # Backward pass
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f"Època {epoch + 1}/{num_epochs}, Pèrdua: {running_loss / len(train_loader)}")

torch.save(model, "namemodel.pt")
# Out:
# Loaded pretrained weights for efficientnet-b1
# 4.92567253112793
# 1.8264293670654297
# 1.0971027612686157
# 1.2289905548095703
# 1.3202675580978394
# 1.3278244733810425
# 1.3378056287765503
# 1.2777177095413208
# 1.2343087196350098
# 1.050007939338684
# 1.1341971158981323
# 1.1074469089508057
# 1.1363857984542847
# 1.0133472681045532
# 1.0084476470947266
# 1.0826798677444458
# 1.066153645515442
# 0.8579511046409607
# 0.8975335955619812
# 0.9165595769882202
# 0.9968633055686951
# 0.9431298971176147
# 0.8825764060020447
# 0.9313268065452576
# 0.9302706122398376
# 0.8769850134849548
# 0.8759416937828064
# 0.9203828573226929
# 0.8766920566558838
# 0.9258091449737549
# 0.8668561577796936
# 0.857090175151825
# 0.8217349648475647
# 0.752528965473175
# 0.6973828673362732
# 0.7544535994529724
# 0.7197142839431763
# 0.7534515261650085
# 0.7572476863861084
# 0.7982320189476013
# 0.789896547794342
# 0.7677843570709229
# 0.7407808303833008
# 0.8235841989517212
# 0.8091855645179749
# 0.6795288324356079
# 0.706045925617218
# 0.7874622344970703
# 0.7777843475341797
# 0.7541196346282959
# 0.7428664565086365
# 0.6570406556129456
# 0.8349291086196899
# 0.7498665452003479
# 0.7426002025604248
# 0.7908170819282532
# 0.6791656017303467
# 0.7855424284934998
# 0.6996144652366638
# 0.7226048111915588
# 0.5792253017425537
# 0.6891224384307861
# 0.6758580207824707
# 0.6158732771873474
# Època 1/1, Pèrdua: 0.9591687293723226

# %% [markdown]
# ### Loading trained parameters

# %%
model_guillem = MangoNet(num_channels=11*(33+1),drop=0.5)
model_guillem.load_state_dict(torch.load('/content/drive/MyDrive/params4b2'))
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b2-8bb594d6.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b2-8bb594d6.pth
# 100%|██████████| 35.1M/35.1M [00:00<00:00, 98.4MB/s]
# <ipython-input-12-e549e1668c76>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_guillem.load_state_dict(torch.load('/content/drive/MyDrive/params4b2'))
# Loaded pretrained weights for efficientnet-b2
# <All keys matched successfully>

# %%
class TestLoader(Dataset):
    def __init__(self, csv_file, image_dir, transform=None):
        """
        Inicialitza el conjunt de dades personalitzat.

        Args:
            csv_file (str): El camí al fitxer CSV amb les etiquetes.
            image_dir (str): El directori que conté les imatges.
            transform (callable, optional): Transformacions a aplicar a les imatges.
        """
        self.img_labels = pd.read_csv(csv_file)[:4096]  # Carrega el CSV amb les etiquetes
        self.img_labels['filename'] = self.img_labels['filename'].astype(str)
        self.img_labels = self.img_labels.drop(columns=['cod_modelo_color'])
        self.img_dir = image_dir  # Directori de les imatges
        self.transform = transform  # Transformacions (per exemple, redimensionar, normalitzar)

        # Preparem les etiquetes
        self.label_columns = self.img_labels.columns.difference(['filename'])

        # Codificació de les etiquetes si són categòriques
        self.label_encoders = {}
        for col in self.label_columns:
            le = LabelEncoder()
            self.img_labels[col] = le.fit_transform(self.img_labels[col])  # Codifiquem les etiquetes
            self.label_encoders[col] = le  # Guardem l'encoder per a futures prediccions


    def __len__(self):
        """Retorna la mida total del conjunt de dades."""
        return len(self.img_labels)

    def __getitem__(self, index):
        """
        Obté una imatge i la seva etiqueta corresponent.

        Args:
            index (int): Índex de la imatge i etiqueta a recuperar.

        Returns:
            tuple: (imatge, etiqueta) on l'imatge és un tensor i l'etiqueta és un tensor.
        """
        # Obtenir el camí de la imatge
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[index, 0])  # 'filename' és a la primera columna
        image = read_image(img_path)  # Obrim l'imatge i la convertim a RGB



        # Aplica transformacions si n'hi ha
        if self.transform:
            image = self.transform(image)


        label = self.img_labels.iloc[index,1:]
        label = label.values.astype('int')
        image = image.type(torch.float32)
        return image, self.img_labels['filename'].loc[index]

# %%
dataset = CustomDataset(csv_file='/content/drive/MyDrive/clean_data.csv', image_dir='/content/archive/images/images', transform=None)

# %% [markdown]
# ### Computing predictions for the test dataset

# %% [markdown]
# #### Without batches

# %%
# Load the CSV containing image paths
test_data = pd.read_csv('/content/test_data (1).csv').drop_duplicates(subset=['cod_modelo_color'])
image_dir = '/content/archive/images/images'
model_guillem = model_guillem.to(device)  # Ensure model is on the correct device
model_guillem.eval()
ID=0

rows_output = pd.DataFrame(columns=['test_id', 'des_value'])

# Iterate through image paths in the CSV
for index, row in test_data.iterrows():
    filename = row['des_filename']  # Assuming 'filename' column contains image paths
    img_path = os.path.join(image_dir, filename)


    if not os.path.exists(img_path) or os.path.getsize(img_path) == 0: continue
    # Load and preprocess the image
    image = read_image(img_path)
    image = image.type(torch.float32)
    image = image.unsqueeze(0)  # Add batch dimension
    image = image.to(device)    # Move to device


    # Make prediction
    pred = model_guillem(image)
    pred_np = pred.cpu().detach().numpy()
    pred_labels = np.argmax(pred_np, axis=1)

    # Get labels and encoders from the dataset used for training (dataset)
    tags = dataset.label_encoders.keys()
    d = {}

    for i, t in enumerate(tags):
        row_id = filename[:11]  # Extract row ID from filename
        encoder = dataset.label_encoders[t]
        label_for_tag = pred_labels[0, i]
        try: d[t] = encoder.inverse_transform([label_for_tag])[0]
        except: d[t] = 'INVALID'

        row_data = {'test_id': row_id + '_' + t, 'des_value': d[t]}
        rows_output = pd.concat([rows_output, pd.DataFrame([row_data])], ignore_index=True)
# Save predictions to CSV
rows_output.to_csv('MangoLoco-RandomGuess.csv', index=False)

# %% [markdown]
# #### With batches

# %%
# Configuració
batch_size = 32
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Carrega el CSV i inicialitza el model
test_data = pd.read_csv('/content/archive/test_data.csv').drop_duplicates(subset=['cod_modelo_color'])
image_dir = '/content/archive/images/images'
model_guillem = model_guillem.to(device)
model_guillem.eval()

rows_output = pd.DataFrame(columns=['test_id', 'des_value'])

# Variables per acumular imatges i noms d'arxiu
image_batch = []
filename_batch = []

ID=0
# Iterar sobre el CSV
for index, row in test_data.iterrows():
    filename = row['des_filename']
    img_path = os.path.join(image_dir, filename)

    # Comprovar si la imatge és vàlida
    if not os.path.exists(img_path) or os.path.getsize(img_path) == 0:
        print(img_path)
        continue

    # Carregar i preprocessar la imatge
    image = read_image(img_path).type(torch.float32)
    image_batch.append(image)
    filename_batch.append(filename)

    # Si hem acumulat un lot complet, fem prediccions
    if len(image_batch) == batch_size or index == len(test_data) - 1:
        # Combinar les imatges en un tensor i moure-les al dispositiu
        image_tensor = torch.stack(image_batch).to(device)

        # Prediccions
        preds = model_guillem(image_tensor)
        preds_np = preds.cpu().detach().numpy()
        pred_labels = np.argmax(preds_np, axis=1)

        # Assignar etiquetes i emmagatzemar resultats
        for i, fname in enumerate(filename_batch):
            tags = dataset.label_encoders.keys()
            d = {}

            for j, t in enumerate(tags):
                row_id = fname[:11]  # Extreure ID del nom de l'arxiu
                encoder = dataset.label_encoders[t]
                label_for_tag = pred_labels[i, j]
                try:
                    d[t] = encoder.inverse_transform([label_for_tag])[0]
                except:
                    d[t] = 'INVALID'

                row_data = {'test_id': row_id + '_' + t, 'des_value': d[t]}
                rows_output = pd.concat([rows_output, pd.DataFrame([row_data])], ignore_index=True)

        # Netejar el lot per processar el següent
        image_batch = []
        filename_batch = []
# Guardar les prediccions
rows_output.to_csv('MangoLoco-RandomGuess.csv', index=False)
